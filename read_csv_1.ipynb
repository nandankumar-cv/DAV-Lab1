# %%
import pandas as pd

raw = pd.read_csv("C:\\Users\\user\\ecommerce_sales_analytics_5000.csv")
print(raw.head())
# Out:
#    order_id order_date  customer_id product_category region  quantity  \
# 0     10001   1/1/2022         1102           Beauty  South         7
# 1     10002   1/2/2022         1435         Clothing  South         7
# 2     10003   1/3/2022         1860           Beauty   East         3
# 3     10004   1/4/2022         1270      Electronics   West         5
# 4     10005   1/5/2022         1106         Clothing   West         5
#
#    unit_price  discount payment_method  delivery_days  customer_rating  \
# 0      373.65      0.28         Wallet             10              4.7
# 1       47.74      0.09           Card              6              3.9
# 2      311.28      0.31            COD              6              2.5
# 3      524.47      0.02         Wallet              6              1.6
# 4      139.87      0.33         Wallet              4              4.9
#
#    revenue
# 0  1883.20
# 1   304.10
# 2   644.35
# 3  2569.90
# 4   468.56

# %%
import pandas as pd

raw = pd.read_csv("C:\\Users\\user\\ecommerce_sales_analytics_5000.csv")

raw["order_id"]
# Out:
# 0       10001
# 1       10002
# 2       10003
# 3       10004
# 4       10005
#         ...
# 4995    14996
# 4996    14997
# 4997    14998
# 4998    14999
# 4999    15000
# Name: order_id, Length: 5000, dtype: int64

# %%
import pandas as pd

raw = pd.read_csv("C:\\Users\\user\\ecommerce_sales_analytics_5000.csv")

raw["order_id"]
h_profit = raw[raw["revenue"] > 4000]
print(h_profit)
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 809      10810  3/20/2024         1890      Electronics  South         7
# 2214     12215  1/24/2028         1113      Electronics  South         7
# 3101     13102  6/29/2030         1699           Beauty   East         7
# 4883     14884  5/16/2035         1146      Electronics  South         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# 809       594.42      0.01           Card              4              4.9
# 2214      591.15      0.02         Wallet              1              3.2
# 3101      596.12      0.04            COD              6              3.0
# 4883      583.31      0.00           Card              5              4.4
#
#       revenue
# 809   4119.33
# 2214  4055.29
# 3101  4005.93
# 4883  4083.17

# %%
import pandas as pd

raw = pd.read_csv("C:\\Users\\user\\ecommerce_sales_analytics_5000.csv")

h_profit = raw[raw["region"] == "North"]
print(h_profit)
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 7        10008   1/8/2022         1020           Beauty  North         6
# 16       10017  1/17/2022         1099         Clothing  North         3
# 21       10022  1/22/2022         1308             Home  North         2
# 24       10025  1/25/2022         1491         Clothing  North         4
# 26       10027  1/27/2022         1805             Home  North         7
# ...        ...        ...          ...              ...    ...       ...
# 4982     14983  8/23/2035         1745         Clothing  North         1
# 4986     14987  8/27/2035         1187         Clothing  North         6
# 4991     14992   9/1/2035         1183             Home  North         2
# 4992     14993   9/2/2035         1110             Home  North         2
# 4996     14997   9/6/2035         1294           Beauty  North         3
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
import pandas as pd

raw = pd.read_csv("C:\\Users\\user\\ecommerce_sales_analytics_5000.csv")

print(raw.shape)
# Out:
# (5000, 12)

# %%
import pandas as pd

raw = pd.read_csv("C:\\Users\\user\\ecommerce_sales_analytics_5000.csv")

print(raw.dtypes)
# Out:
# order_id              int64
# order_date              str
# customer_id           int64
# product_category        str
# region                  str
# quantity              int64
# unit_price          float64
# discount            float64
# payment_method          str
# delivery_days         int64
# customer_rating     float64
# revenue             float64
# dtype: object

# %%
import pandas as pd

raw = pd.read_csv("C:\\Users\\user\\ecommerce_sales_analytics_5000.csv")

print(raw.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          5000 non-null   int64
#  1   order_date        5000 non-null   str
#  2   customer_id       5000 non-null   int64
#  3   product_category  5000 non-null   str
#  4   region            5000 non-null   str
#  5   quantity          5000 non-null   int64
#  6   unit_price        5000 non-null   float64
#  7   discount          5000 non-null   float64
#  8   payment_method    5000 non-null   str
#  9   delivery_days     5000 non-null   int64
#  10  customer_rating   5000 non-null   float64
#  11  revenue           5000 non-null   float64
# dtypes: float64(4), int64(4), str(4)
# memory usage: 468.9 KB
# None

# %%
raw.describe()
# Out:
#            order_id  customer_id     quantity   unit_price     discount  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean   12500.500000  1505.701200     4.044800   308.418774     0.179984
# std     1443.520003   290.836902     2.020398   169.259369     0.101404
# min    10001.000000  1000.000000     1.000000    15.150000     0.000000
# 25%    11250.750000  1253.000000     2.000000   161.895000     0.090000
# 50%    12500.500000  1510.000000     4.000000   309.890000     0.180000
# 75%    13750.250000  1761.000000     6.000000   455.557500     0.270000
# max    15000.000000  1999.000000     7.000000   599.960000     0.350000
#
#        delivery_days  customer_rating      revenue
# count    5000.000000      5000.000000  5000.000000
# mean        6.118800         2.973980  1021.955148
# std         3.153264         1.157722   825.584219
# min         1.000000         1.000000    11.210000
# 25%         3.000000         2.000000   354.527500
# ...

# %%
raw["unit_price"].mean()
# Out:
# np.float64(308.41877400000004)

# %%
raw["revenue"].unique()
# Out:
# array([1883.2 ,  304.1 ,  644.35, ...,  176.06,  437.38, 1069.9 ],
#       shape=(4940,))

# %%
raw["region"].value_counts()
# Out:
# region
# West     1289
# North    1276
# East     1227
# South    1208
# Name: count, dtype: int64

# %%
raw["unit_price"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: unit_price, Length: 5000, dtype: bool

# %%
raw.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          5000 non-null   int64
#  1   order_date        5000 non-null   str
#  2   customer_id       5000 non-null   int64
#  3   product_category  5000 non-null   str
#  4   region            5000 non-null   str
#  5   quantity          5000 non-null   int64
#  6   unit_price        5000 non-null   float64
#  7   discount          5000 non-null   float64
#  8   payment_method    5000 non-null   str
#  9   delivery_days     5000 non-null   int64
#  10  customer_rating   5000 non-null   float64
#  11  revenue           5000 non-null   float64
# dtypes: float64(4), int64(4), str(4)
# memory usage: 468.9 KB
